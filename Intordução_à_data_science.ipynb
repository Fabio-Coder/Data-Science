# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabio-Coder/Data-Science/blob/master/Intordu%C3%A7%C3%A3o_%C3%A0_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = 'Fabio'
print(nome)
# Out:
# Fabio
